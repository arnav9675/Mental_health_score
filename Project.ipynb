# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Student Social Media And Mental Health Impact.csv")

# %%
#look the first 5 rows
df.head()
# Out:
#    Age  Gender Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0   21    Male   Other  Undergraduate           Facebook     Networking
# 1   23  Female   Other       Graduate           LinkedIn      Education
# 2   22    Male  Canada  Undergraduate          Instagram  Entertainment
# 3   18    Male   Other    High School           Snapchat  Entertainment
# 4   24  Female   Other       Graduate           Facebook     Networking
#
#    Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  Physical_Activity_Hours  \
# 0                    4.0            134          4.5                      2.2
# 1                    1.6             73          7.0                      2.4
# 2                    4.6            166          4.0                      1.8
# 3                    7.0            220          1.0                      1.7
# 4                    7.5            237          1.0                      1.1
#
#    Sleep_Hours_Per_Night Stress_Level  Mental_Health_Score
# ...

# %%
#Look at the shape of the data
df.shape
# Out:
# (5000, 13)

# %%
#get the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      5000 non-null   int64
#  1   Gender                   5000 non-null   object
#  2   Country                  5000 non-null   object
#  3   Academic_Level           5000 non-null   object
#  4   Most_Used_Platform       5000 non-null   object
#  5   Purpose_Of_Use           5000 non-null   object
#  6   Avg_Daily_Usage_Hours    5000 non-null   float64
#  7   Daily_Unlocks            5000 non-null   int64
#  8   Study_Hours              5000 non-null   float64
#  9   Physical_Activity_Hours  5000 non-null   float64
#  10  Sleep_Hours_Per_Night    5000 non-null   float64
#  11  Stress_Level             5000 non-null   object
#  12  Mental_Health_Score      5000 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# ...

# %%
#check the null values
df.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Country                    0
# Academic_Level             0
# Most_Used_Platform         0
# Purpose_Of_Use             0
# Avg_Daily_Usage_Hours      0
# Daily_Unlocks              0
# Study_Hours                0
# Physical_Activity_Hours    0
# Sleep_Hours_Per_Night      0
# Stress_Level               0
# Mental_Health_Score        0
# dtype: int64

# %%
# Remove the duplicate rows 
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (4998, 13)

# %%
# get a descripted values of the data
df.describe()
# Out:
#                Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  4998.000000            4998.000000    4998.000000  4998.000000
# mean     20.822129               5.078491     171.455582     3.008403
# std       1.736774               1.654097      42.859829     1.636831
# min      18.000000               1.000000      62.000000     0.300000
# 25%      19.000000               3.800000     140.000000     1.500000
# 50%      21.000000               5.000000     171.000000     2.800000
# 75%      22.000000               6.300000     204.000000     4.200000
# max      24.000000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              4998.000000            4998.000000          4998.000000
# mean                  1.750760               6.634654             6.231152
# std                   0.668406               1.221561             1.278476
# ...

# %% [markdown]
# # **EDA(data anylysis)**

# %%
# choose the target coloumn and then see the distribution
sns.kdeplot(df["Mental_Health_Score"])
# Out:
# <Axes: xlabel='Mental_Health_Score', ylabel='Density'>

# %%
# see the corrilation of the data with th target coloumn and corrliton between numerical coloumn
df.corr(numeric_only=True)
# Out:
#                               Age  Avg_Daily_Usage_Hours  Daily_Unlocks  \
# Age                      1.000000              -0.069961      -0.074337
# Avg_Daily_Usage_Hours   -0.069961               1.000000       0.960190
# Daily_Unlocks           -0.074337               0.960190       1.000000
# Study_Hours              0.082860              -0.878665      -0.853359
# Physical_Activity_Hours  0.013071              -0.625764      -0.602845
# Sleep_Hours_Per_Night    0.088545              -0.808370      -0.781820
# Mental_Health_Score      0.100464              -0.816485      -0.790830
#
#                          Study_Hours  Physical_Activity_Hours  \
# Age                         0.082860                 0.013071
# Avg_Daily_Usage_Hours      -0.878665                -0.625764
# Daily_Unlocks              -0.853359                -0.602845
# Study_Hours                 1.000000                 0.560618
# Physical_Activity_Hours     0.560618                 1.000000
# ...

# %%
# this is heatmap to see the corrilation
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
# see all the unique values 
df["Stress_Level"].unique()
# Out:
# array(['Medium', 'Low', 'Very High', 'High'], dtype=object)

# %%
order=['Low','Medium', 'High', 'Very High']

# %%
sns.boxenplot(x=df["Stress_Level"],y=df["Mental_Health_Score"],order=order)
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Mental_Health_Score'>

# %%
sns.scatterplot(x=df["Avg_Daily_Usage_Hours"],y=df["Mental_Health_Score"])
# Out:
# <Axes: xlabel='Avg_Daily_Usage_Hours', ylabel='Mental_Health_Score'>

# %%
sns.scatterplot(x=df["Sleep_Hours_Per_Night"],y=df["Mental_Health_Score"])
# Out:
# <Axes: xlabel='Sleep_Hours_Per_Night', ylabel='Mental_Health_Score'>

# %%
sns.scatterplot(x=df["Physical_Activity_Hours"],y=df["Mental_Health_Score"])
# Out:
# <Axes: xlabel='Physical_Activity_Hours', ylabel='Mental_Health_Score'>

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
sns.countplot(data=df,x="Most_Used_Platform")
# Out:
# <Axes: xlabel='Most_Used_Platform', ylabel='count'>

# %%
platform=df["Most_Used_Platform"].value_counts()

# %%
plt.figure(figsize=(12,4))
sns.countplot(x=df["Most_Used_Platform"],order=df["Most_Used_Platform"].value_counts().index)
# Out:
# <Axes: xlabel='Most_Used_Platform', ylabel='count'>

# %% [markdown]
# **Checking Outliers**

# %%
numerical_feature=df.select_dtypes(include="number")
Q1= numerical_feature.quantile(0.25)
Q3= numerical_feature.quantile(0.75)
IQR= Q3-Q1

lower_bound=Q1 - 1.5*IQR
upper_bound=Q1 + 1.5*IQR

outlier=(numerical_feature<lower_bound) | (numerical_feature>upper_bound)

# %%
outlier.sum()
# Out:
# Age                        422
# Avg_Daily_Usage_Hours      378
# Daily_Unlocks              343
# Study_Hours                401
# Physical_Activity_Hours    485
# Sleep_Hours_Per_Night      415
# Mental_Health_Score        410
# dtype: int64

# %% [markdown]
# # **Data Cleaning**

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  4998.000000            4998.000000    4998.000000  4998.000000
# mean     20.822129               5.078491     171.455582     3.008403
# std       1.736774               1.654097      42.859829     1.636831
# min      18.000000               1.000000      62.000000     0.300000
# 25%      19.000000               3.800000     140.000000     1.500000
# 50%      21.000000               5.000000     171.000000     2.800000
# 75%      22.000000               6.300000     204.000000     4.200000
# max      24.000000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              4998.000000            4998.000000          4998.000000
# mean                  1.750760               6.634654             6.231152
# std                   0.668406               1.221561             1.278476
# ...

# %%
#1, drop duplicates
df=df.drop_duplicates()

# 2. coverting unrealistic orn negivet or negative values
df["Physical_Activity_Hours"]=df["Physical_Activity_Hours"].clip(lower=0)

# %% [markdown]
# # **Skewness**

# %%
num_col=df.select_dtypes("number")
num_col.skew()
# Out:
# Age                        0.155008
# Avg_Daily_Usage_Hours      0.005575
# Daily_Unlocks              0.002309
# Study_Hours                0.436125
# Physical_Activity_Hours    0.053288
# Sleep_Hours_Per_Night      0.123919
# Mental_Health_Score        0.207086
# dtype: float64

# %% [markdown]
# # **Feature Enginnering**

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
top_countries=df["Country"].value_counts().index[:10].tolist()

# %%
def group_countries(country):
    if country in top_countries:
        return country
    else:
        return "Other"

# %%
df["Country"]=df["Country"].apply(group_countries)

# %%
df["Country"].value_counts()
# Out:
# Country
# Other        3231
# India         389
# USA           354
# Canada        230
# Australia     198
# UK            185
# Germany       136
# Mexico         94
# Turkey         94
# France         87
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
skewws_col=["Study_Hours"]
other_numererical_col=["Age","Avg_Daily_Usage_Hours","Daily_Unlocks","Physical_Activity_Hours","Sleep_Hours_Per_Night"]
ordinaal_col=["Stress_Level"]
normal_col=['Gender',"Academic_Level","Most_Used_Platform","Purpose_Of_Use","Country"]

feature_col=skewws_col+other_numererical_col+ordinaal_col+normal_col

# %%
from sklearn.model_selection import train_test_split
X=df[feature_col]
y=df["Mental_Health_Score"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer,StandardScaler,OrdinalEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
#1. For skewed Feature 
skew_pipeline=Pipeline(
    steps=[
        ("log_transfornm",FunctionTransformer(np.log1p)),
        ("scale",StandardScaler())])
#2. For Numeric feature 
plain_numerical_pipe=Pipeline(steps=[
    ("scale",StandardScaler())])
#3.normal Pipeline (ordinal)
ordinal_pipeline=Pipeline(steps=[
    ("ore",OrdinalEncoder(categories=[["Low","Medium","High","Very High"]]))
])

#4. Nominal_pipeline
nominal_pipeline=Pipeline(steps=[
    ("ohe",OneHotEncoder(handle_unknown="ignore"))
])

pre_processor=ColumnTransformer(transformers=[
    ("Skwed_pipeline",skew_pipeline,skewws_col),
    ("Plain_Numeric",plain_numerical_pipe,other_numererical_col),
    ("Ordinal",ordinal_pipeline,ordinaal_col),
    ("Nominal",nominal_pipeline,normal_col)
])

# %% [markdown]
# # **Model Building**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

lr_pipeline=Pipeline(steps=[
    ("preprocessor",pre_processor),
    ("regressor",LinearRegression())
])

lr_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Skwed_pipeline',
#                                                   Pipeline(steps=[('log_transfornm',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Study_Hours']),
#                                                  ('Plain_Numeric',
#                                                   Pipeline(steps=[('scale',
#                                                                    StandardScaler())]),
#                                                   ['Age',
#                                                    'Avg_Daily_Usage_Hours',
#                                                    'Daily_Unlocks',
# ...

# %%
lr_pred=lr_pipeline.predict(X_test)
lr_pred_train=lr_pipeline.predict(X_train)


lr_r2_testing=r2_score(y_test,lr_pred)
lr_r2_training=r2_score(y_train,lr_pred_train)
lr_mae=mean_absolute_error(y_test,lr_pred)
lr_mse=mean_squared_error(y_test,lr_pred)

# %%
print("Accuracy of testing",lr_r2_testing)
print("Accuracy of Training",lr_r2_training)
print("MAE",lr_mae)
print("MSE",lr_mse)
# Out:
# Accuracy of testing 0.739794461743302
# Accuracy of Training 0.7236771199387539
# MAE 0.5361775634720183
# MSE 0.45701905273488

# %%
X_train.shape
# Out:
# (3498, 12)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_pipeline = Pipeline(steps=[
    ('preprocessor', pre_processor),
    ('random forest', RandomForestRegressor(random_state=42))
])

rf_pipeline.fit(X_train, y_train)
rf_preds          = rf_pipeline.predict(X_test)
rf_preds_training = rf_pipeline.predict(X_train)

rf_r2_testing  = r2_score(y_test, rf_preds)
rf_r2_training = r2_score(y_train, rf_preds_training)
rf_mae         = mean_absolute_error(y_test, rf_preds)

print(f"Accuracy of Training {rf_r2_training}")
print(f"Accuracy of Testing {rf_r2_testing}")
print(f"MAE : {rf_mae}")
# Out:
# Accuracy of Training 0.9809069341581819
# Accuracy of Testing 0.8780167461546369
# MAE : 0.34650236666666673

# %%
rf_pred=rf_pipeline.predict(X_test)
rf_pred_train=rf_pipeline.predict(X_train)

rf_r2_test=r2_score(y_test,rf_pred)
rf_r2_train=r2_score(y_train,rf_pred_train)
r2_mae=mean_absolute_error(y_test,rf_pred)

# %%
print("rf_r2_test",rf_r2_test)
print("rf_r2_train",rf_r2_train)
print("MAE",r2_mae)
# Out:
# rf_r2_test 0.8780167461546369
# rf_r2_train 0.9809069341581819
# MAE 0.34650236666666673

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'random forest__n_estimators'       : [100,200,300],
    'random forest__max_depth'         : [5,10,15],
    'random forest__min_samples_split' : [2,5,10],
    'random forest__min_samples_leaf'  : [1,2,4]
}

random_search = RandomizedSearchCV(
    estimator=rf_pipeline,
    param_distributions=param_grid,
    n_iter = 15,
    cv = 5,
    scoring='r2',
    random_state=42,
    n_jobs =-1 #processor free
)

random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('Skwed_pipeline',
#                                                                                Pipeline(steps=[('log_transfornm',
#                                                                                                 FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                                                ('scale',
#                                                                                                 StandardScaler())]),
#                                                                                ['Study_Hours']),
#                                                                               ('Plain_Numeric',
#                                                                                Pipeline(steps=[('scale',
# ...

# %%
rf_best_pipeline = random_search.best_estimator_
rf_best_preds    = rf_best_pipeline.predict(X_test)

print(f"R2 Score for random forest after hyperparameter tuning {r2_score(y_test, rf_best_preds)}")
print(f"MAE Score for random forest after hyperparameter tuning {mean_absolute_error(y_test, rf_best_preds)}")
# Out:
# R2 Score for random forest after hyperparameter tuning 0.8652257547733472
# MAE Score for random forest after hyperparameter tuning 0.36866505007865863

# %%
from sklearn.metrics import mean_squared_error

# Calculate RMSE for Linear Regression
lr_rmse = np.sqrt(mean_squared_error(y_test, lr_pred))

# Calculate RMSE for default Random Forest
rf_rmse = np.sqrt(mean_squared_error(y_test, rf_preds))

# Calculate RMSE for tuned Random Forest
rf_tuned_preds          = random_search.best_estimator_.predict(X_test)
rf_tuned_rmse           = np.sqrt(mean_squared_error(y_test, rf_tuned_preds))
rf_tuned_training_preds = random_search.best_estimator_.predict(X_train)
r2_tuned_training       = r2_score(y_train, rf_tuned_training_preds)
rf_tuned_mae            = mean_absolute_error(y_test, rf_tuned_preds)
rf_tuned_r2             = r2_score(y_test, rf_tuned_preds)


# Create a DataFrame to consolidate results
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest (default)', 'Random Forest (tuned)'],
    'R2': [lr_r2_testing, rf_r2_testing, rf_tuned_r2],
    'Training R2': [lr_r2_training, rf_r2_training, r2_tuned_training],
    'MAE': [lr_mae, rf_mae, rf_tuned_mae],
    'RMSE': [lr_rmse, rf_rmse, rf_tuned_rmse]
})
print(results)
# Out:
#                      Model        R2  Training R2       MAE      RMSE
# 0        Linear Regression  0.739794     0.723677  0.536178  0.676032
# 1  Random Forest (default)  0.878017     0.980907  0.346502  0.462870
# 2    Random Forest (tuned)  0.865226     0.954656  0.368665  0.486533

# %% [markdown]
# save model in joblib

# %%
import joblib
joblib.dump(rf_pipeline,"Mental_health_model.pkl")
# Out:
# ['Mental_health_model.pkl']

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Gender',
#  'Country',
#  'Academic_Level',
#  'Most_Used_Platform',
#  'Purpose_Of_Use',
#  'Avg_Daily_Usage_Hours',
#  'Daily_Unlocks',
#  'Study_Hours',
#  'Physical_Activity_Hours',
#  'Sleep_Hours_Per_Night',
#  'Stress_Level',
#  'Mental_Health_Score']

# %%
import pickle

# %%
with open("model_final","wb") as file:
    pickle.dump(rf_pipeline,file)

# %%
with open("model_final","rb") as f:
    mp=pickle.load(f)
